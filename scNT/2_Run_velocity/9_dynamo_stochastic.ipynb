# %%
import pandas as pd
import scanpy as sc
import numpy  as np
import os
import sys
import dynamo as dyn

SEED = 2024
np.random.seed(SEED)

# %%
adata = sc.read_h5ad("scNT_HSC_scvelo_process.h5ad")
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 1947 × 2000
#     obs: 'batch', 'cell_type', 'time', 'nGenes', 'nCounts', 'pMito', 'pass_basic_filter', 'spliced_Size_Factor', 'initial_spliced_cell_size', 'total_Size_Factor', 'initial_total_cell_size', 'unspliced_Size_Factor', 'initial_unspliced_cell_size', 'Size_Factor', 'initial_cell_size', 'new_Size_Factor', 'initial_new_cell_size', 'ntr', 'initial_size_unspliced', 'initial_size_spliced', 'initial_size', 'n_counts'
#     var: 'gene_name_mapping', 'query', 'scopes', '_id', '_score', 'symbol', 'nCells', 'nCounts', 'pass_basic_filter', 'score', 'means', 'dispersions', 'dispersions_norm', 'highly_variable'
#     uns: 'PCs', 'batch_colors', 'cell_type_colors', 'dynamics', 'explained_variance_ratio_', 'feature_selection', 'genes_to_use', 'grid_velocity_umap', 'neighbors', 'pca_mean', 'pp', 'velocyto_SVR'
#     obsm: 'X_pca', 'X_umap', 'scNT_velocity_umap', 'velocity_umap'
#     layers: 'M_n', 'M_nn', 'M_s', 'M_ss', 'M_t', 'M_tn', 'M_tt', 'M_u', 'M_us', 'M_uu', 'Ms', 'Mu', 'X_new', 'X_spliced', 'X_total', 'X_unspliced', 'new', 'spliced', 'total', 'unspliced', 'velocity_N', 'velocity_T', 'velocity_alpha_minus_gamma_s'
#     obsp: 'connectivities', 'cosine_transition_matrix', 'distances', 'moments_con'

# %%
adata2 = adata.copy()
adata2.layers = None

# adata2.layers['Mu'] = adata.layers['Mu']
# adata2.layers['Ms'] = adata.layers['Ms']
adata2.layers['unspliced'] = adata.layers['unspliced']
adata2.layers['spliced'] = adata.layers['spliced']

print(adata2)
# Out:
# AnnData object with n_obs × n_vars = 1947 × 2000
#     obs: 'batch', 'cell_type', 'time', 'nGenes', 'nCounts', 'pMito', 'pass_basic_filter', 'spliced_Size_Factor', 'initial_spliced_cell_size', 'total_Size_Factor', 'initial_total_cell_size', 'unspliced_Size_Factor', 'initial_unspliced_cell_size', 'Size_Factor', 'initial_cell_size', 'new_Size_Factor', 'initial_new_cell_size', 'ntr', 'initial_size_unspliced', 'initial_size_spliced', 'initial_size', 'n_counts'
#     var: 'gene_name_mapping', 'query', 'scopes', '_id', '_score', 'symbol', 'nCells', 'nCounts', 'pass_basic_filter', 'score', 'means', 'dispersions', 'dispersions_norm', 'highly_variable'
#     uns: 'PCs', 'batch_colors', 'cell_type_colors', 'dynamics', 'explained_variance_ratio_', 'feature_selection', 'genes_to_use', 'grid_velocity_umap', 'neighbors', 'pca_mean', 'pp', 'velocyto_SVR'
#     obsm: 'X_pca', 'X_umap', 'scNT_velocity_umap', 'velocity_umap'
#     layers: 'unspliced', 'spliced'
#     obsp: 'connectivities', 'cosine_transition_matrix', 'distances', 'moments_con'

# %%
dyn.pp.recipe_monocle(adata2)
dyn.tl.dynamics(adata2, model='stochastic', cores=10)
# Out:
# |-----? dynamo.preprocessing.deprecated is deprecated.
# |-----> recipe_monocle_keep_filtered_cells_key is None. Using default value from DynamoAdataConfig: recipe_monocle_keep_filtered_cells_key=True
# |-----> recipe_monocle_keep_filtered_genes_key is None. Using default value from DynamoAdataConfig: recipe_monocle_keep_filtered_genes_key=True
# |-----> recipe_monocle_keep_raw_layers_key is None. Using default value from DynamoAdataConfig: recipe_monocle_keep_raw_layers_key=True
# |-----> apply Monocole recipe to adata...
# |-----> ensure all cell and variable names unique.
# |-----> ensure all data in different layers in csr sparse matrix format.
# |-----> ensure all labeling data properly collapased
# |-----? dynamo detects your data is size factor normalized and/or log transformed. If this is not right, plese set `normalized = False.
# |-----> filtering cells...
# |-----> 1673 cells passed basic filters.
# |-----> filtering gene...
# |-----> 119 genes passed basic filters.
# |-----> calculating size factor...
# |-----? only 119 genes passed basic filtering, but you requested 2000 genes for feature selection. Try lowering the gene selection stringency: {'min_expr_cells': 0, 'min_expr_avg': 0, 'max_expr_avg': inf, 'svr_gamma': None, 'winsorize': False, 'winsor_perc': (1, 99.5), 'sort_inverse': False}
# |-----> selecting genes in layer: X, sort method: SVR...
# |-----> applying PCA ...
# /tmp/ipykernel_882102/519099300.py:1: DeprecationWarning: recipe_monocle is deprecated and will be removed in a future release. Please update your code to use the new replacement function.
#   dyn.pp.recipe_monocle(adata2)
# |-----> <insert> X_pca to obsm in AnnData Object.
# |-----> cell cycle scoring...
# |-----> computing cell phase...
# |-----> [Cell Phase Estimation] completed [5.1807s]
# |-----> [Cell Cycle Scores Estimation] completed [0.1403s]
# |-----> [recipe_monocle preprocess] completed [0.7824s]
# |-----> dynamics_del_2nd_moments_key is None. Using default value from DynamoAdataConfig: dynamics_del_2nd_moments_key=False
# |-----------> removing existing M layers:[]...
# |-----------> making adata smooth...
# |-----> calculating first/second moments...
# |-----> [moments calculation] completed [8.7819s]
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /tmp/ipykernel_882102/519099300.py in <module>
#       1 dyn.pp.recipe_monocle(adata2)
# ----> 2 dyn.tl.dynamics(adata2, model='stochastic', cores=10)
#
# ~/miniconda3/envs/Dynamo/lib/python3.8/site-packages/dynamo/tools/dynamics.py in dynamics(adata, filter_gene_mode, use_smoothed, assumption_mRNA, assumption_protein, model, est_method, NTR_vel, group, protein_names, concat_data, log_unnormalized, one_shot_method, fraction_for_deg, re_smooth, sanity_check, del_2nd_moments, cores, tkey, **est_kwargs)
#     515                     # experiment_type can be `kin` also and by default use
#     516                     # conventional method to estimate k but correct for time
# --> 517                     est.fit(**est_kwargs)
#     518
#     519             alpha, beta, gamma, eta, delta = est.parameters.values()
#
# ~/miniconda3/envs/Dynamo/lib/python3.8/site-packages/dynamo/estimation/csc/velocity.py in fit(self, intercept, perc_left, perc_right, clusters, one_shot_method)
#     650                     else:
#     651                         pool = ThreadPool(cores)
# --> 652                         res = pool.starmap(
#     653                             self.fit_gamma_stochastic,
#     654                             zip(
#
# ~/miniconda3/envs/Dynamo/lib/python3.8/multiprocessing/pool.py in starmap(self, func, iterable, chunksize)
#     370         `func` and (a, b) becomes func(a, b).
#     371         '''
# --> 372         return self._map_async(func, iterable, starmapstar, chunksize).get()
#     373
#     374     def starmap_async(self, func, iterable, chunksize=None, callback=None,
#
# ~/miniconda3/envs/Dynamo/lib/python3.8/multiprocessing/pool.py in get(self, timeout)
#     766             return self._value
#     767         else:
# --> 768             raise self._value
#     769
#     770     def _set(self, i, obj):
#
# ~/miniconda3/envs/Dynamo/lib/python3.8/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123         job, i, func, args, kwds = task
#     124         try:
# --> 125             result = (True, func(*args, **kwds))
#     126         except Exception as e:
#     127             if wrap_exception and func is not _helper_reraises_exception:
#
# ~/miniconda3/envs/Dynamo/lib/python3.8/multiprocessing/pool.py in starmapstar(args)
#      49
#      50 def starmapstar(args):
# ---> 51     return list(itertools.starmap(args[0], args[1]))
#      52
#      53 #
#
# ~/miniconda3/envs/Dynamo/lib/python3.8/site-packages/dynamo/estimation/csc/velocity.py in fit_gamma_stochastic(self, est_method, u, s, us, ss, perc_left, perc_right, normalize)
#    1687         bs, bf = None, None
#    1688         if est_method.lower() == "gmm":
# -> 1689             k = fit_stochastic_linreg(u[mask], s[mask], us[mask], ss[mask])
#    1690         elif est_method.lower() == "negbin":
#    1691             phi = compute_dispersion(s, ss)
#
# ~/miniconda3/envs/Dynamo/lib/python3.8/site-packages/dynamo/estimation/csc/utils_velocity.py in fit_stochastic_linreg(u, s, us, ss, fit_2_gammas, err_cov)
#     418     else:
#     419         cov = np.diag(E.var(1))
# --> 420     cov_inv = np.linalg.pinv(cov)
#     421
#     422     # generalized least squares
#
# ~/miniconda3/envs/Dynamo/lib/python3.8/site-packages/numpy/core/overrides.py in pinv(*args, **kwargs)
#
# ~/miniconda3/envs/Dynamo/lib/python3.8/site-packages/numpy/linalg/linalg.py in pinv(a, rcond, hermitian)
#    1981         return wrap(res)
#    1982     a = a.conjugate()
# -> 1983     u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    1984
#    1985     # discard small singular values
#
# ~/miniconda3/envs/Dynamo/lib/python3.8/site-packages/numpy/core/overrides.py in svd(*args, **kwargs)
#
# ~/miniconda3/envs/Dynamo/lib/python3.8/site-packages/numpy/linalg/linalg.py in svd(a, full_matrices, compute_uv, hermitian)
#    1640
#    1641         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1642         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1643         u = u.astype(result_t, copy=False)
#    1644         s = s.astype(_realType(result_t), copy=False)
#
# ~/miniconda3/envs/Dynamo/lib/python3.8/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_svd_nonconvergence(err, flag)
#      96
#      97 def _raise_linalgerror_svd_nonconvergence(err, flag):
# ---> 98     raise LinAlgError("SVD did not converge")
#      99
#     100 def _raise_linalgerror_lstsq(err, flag):
#
# LinAlgError: SVD did not converge
